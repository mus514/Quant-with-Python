# %%
import numpy as np
import pandas as pd
from pylab import mpl, plt
plt.style.use('seaborn-v0_8')
mpl.rcParams['font.family'] = 'serif'
# %config InlineBackend.figure_format = 'svg'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
file_name = 'data/tr_eikon_eod_data.csv'
f = open(file_name, 'r')
f.readlines()[:5]
# Out:
# ['Date,AAPL.O,MSFT.O,INTC.O,AMZN.O,GS.N,SPY,.SPX,.VIX,EUR=,XAU=,GDX,GLD\n',
#  '2010-01-01,,,,,,,,,1.4323,1096.35,,\n',
#  '2010-01-04,30.57282657,30.95,20.88,133.9,173.08,113.33,1132.99,20.04,1.4411,1120.0,47.71,109.8\n',
#  '2010-01-05,30.625683660000004,30.96,20.87,134.69,176.14,113.63,1136.52,19.35,1.4368,1118.65,48.17,109.7\n',
#  '2010-01-06,30.138541290000003,30.77,20.8,132.25,174.26,113.71,1137.14,19.16,1.4412,1138.5,49.34,111.51\n']

# %%
data = pd.read_csv(file_name, index_col=0, parse_dates=True)
data.head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-01        NaN     NaN     NaN     NaN     NaN     NaN      NaN    NaN
# 2010-01-04  30.572827  30.950   20.88  133.90  173.08  113.33  1132.99  20.04
# 2010-01-05  30.625684  30.960   20.87  134.69  176.14  113.63  1136.52  19.35
# 2010-01-06  30.138541  30.770   20.80  132.25  174.26  113.71  1137.14  19.16
# 2010-01-07  30.082827  30.452   20.60  130.00  177.67  114.19  1141.69  19.06
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-01  1.4323  1096.35    NaN     NaN
# 2010-01-04  1.4411  1120.00  47.71  109.80
# 2010-01-05  1.4368  1118.65  48.17  109.70
# 2010-01-06  1.4412  1138.50  49.34  111.51
# 2010-01-07  1.4318  1131.90  49.10  110.82

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2216 entries, 2010-01-01 to 2018-06-29
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL.O  2138 non-null   float64
#  1   MSFT.O  2138 non-null   float64
#  2   INTC.O  2138 non-null   float64
#  3   AMZN.O  2138 non-null   float64
#  4   GS.N    2138 non-null   float64
#  5   SPY     2138 non-null   float64
#  6   .SPX    2138 non-null   float64
#  7   .VIX    2138 non-null   float64
#  8   EUR=    2216 non-null   float64
#  9   XAU=    2211 non-null   float64
#  10  GDX     2138 non-null   float64
#  11  GLD     2138 non-null   float64
# dtypes: float64(12)
# memory usage: 225.1 KB

# %%
data['GLD'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
instruments = ['Apple Stock', 'Microsoft Stock',
               'Intel Stock', 'Amazon Stock', 'Goldman Sachs Stock',
               'SPDR S&P 500 ETF Trust', 'S&P 500 Index',
               'VIX Volatility Index', 'EUR/USD Exchange Rate',
               'Gold Price', 'VanEck Vectors Gold Miners ETF',
               'SPDR Gold Trust']

# %%
for ric, name in zip(data.columns, instruments):
    print('{:8s} | {}'.format(ric, name))
# Out:
# AAPL.O   | Apple Stock
# MSFT.O   | Microsoft Stock
# INTC.O   | Intel Stock
# AMZN.O   | Amazon Stock
# GS.N     | Goldman Sachs Stock
# SPY      | SPDR S&P 500 ETF Trust
# .SPX     | S&P 500 Index
# .VIX     | VIX Volatility Index
# EUR=     | EUR/USD Exchange Rate
# XAU=     | Gold Price
# GDX      | VanEck Vectors Gold Miners ETF
# GLD      | SPDR Gold Trust

# %%
# discribe statistics

data.describe().round(2)
# Out:
#         AAPL.O   MSFT.O   INTC.O   AMZN.O     GS.N      SPY     .SPX     .VIX  \
# count  2138.00  2138.00  2138.00  2138.00  2138.00  2138.00  2138.00  2138.00
# mean     93.46    44.56    29.36   480.46   170.22   180.32  1802.71    17.03
# std      40.55    19.53     8.17   372.31    42.48    48.19   483.34     5.88
# min      27.44    23.01    17.66   108.61    87.70   102.20  1022.58     9.14
# 25%      60.29    28.57    22.51   213.60   146.61   133.99  1338.57    13.07
# 50%      90.55    39.66    27.33   322.06   164.43   186.32  1863.08    15.58
# 75%     117.24    54.37    34.71   698.85   192.13   210.99  2108.94    19.07
# max     193.98   102.49    57.08  1750.08   273.38   286.58  2872.87    48.00
#
#           EUR=     XAU=      GDX      GLD
# count  2216.00  2211.00  2138.00  2138.00
# mean      1.25  1349.01    33.57   130.09
# std       0.11   188.75    15.17    18.78
# min       1.04  1051.36    12.47   100.50
# 25%       1.13  1221.53    22.14   117.40
# ...

# %%
data.mean()
# Out:
# AAPL.O      93.455973
# MSFT.O      44.561115
# INTC.O      29.364192
# AMZN.O     480.461251
# GS.N       170.216221
# SPY        180.323029
# .SPX      1802.713106
# .VIX        17.027133
# EUR=         1.248587
# XAU=      1349.014130
# GDX         33.566525
# GLD        130.086590
# dtype: float64

# %%
data.aggregate([min,
                np.mean,
                np.std,
                np.median,
                max])
# Out:
#             AAPL.O      MSFT.O     INTC.O       AMZN.O        GS.N  \
# min      27.435687   23.010000  17.665000   108.610000   87.700000
# mean     93.455973   44.561115  29.364192   480.461251  170.216221
# std      40.551559   19.527712   8.172160   372.307818   42.483935
# median   90.550624   39.660000  27.330000   322.065000  164.430000
# max     193.980000  102.490000  57.080000  1750.080000  273.380000
#
#                SPY         .SPX       .VIX      EUR=         XAU=        GDX  \
# min     102.200000  1022.580000   9.140000  1.038500  1051.360000  12.470000
# mean    180.323029  1802.713106  17.027133  1.248587  1349.014130  33.566525
# std      48.190071   483.337146   5.883428  0.113711   188.745856  15.169564
# median  186.320000  1863.080000  15.585000  1.270250  1292.610000  25.625000
# max     286.580000  2872.870000  48.000000  1.482600  1898.990000  66.630000
#
#               GLD
# min     100.50000
# mean    130.08659
# std      18.78359
# median  124.00500
# ...

# %%
data.diff().round(2).head()
# Out:
#             AAPL.O  MSFT.O  INTC.O  AMZN.O  GS.N   SPY  .SPX  .VIX  EUR=  \
# Date
# 2010-01-01     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN
# 2010-01-04     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN  0.01
# 2010-01-05    0.05    0.01   -0.01    0.79  3.06  0.30  3.53 -0.69 -0.00
# 2010-01-06   -0.49   -0.19   -0.07   -2.44 -1.88  0.08  0.62 -0.19  0.00
# 2010-01-07   -0.06   -0.32   -0.20   -2.25  3.41  0.48  4.55 -0.10 -0.01
#
#              XAU=   GDX   GLD
# Date
# 2010-01-01    NaN   NaN   NaN
# 2010-01-04  23.65   NaN   NaN
# 2010-01-05  -1.35  0.46 -0.10
# 2010-01-06  19.85  1.17  1.81
# 2010-01-07  -6.60 -0.24 -0.69

# %%
data.pct_change().round(3).head()
# Out:
#             AAPL.O  MSFT.O  INTC.O  AMZN.O   GS.N    SPY   .SPX   .VIX   EUR=  \
# Date
# 2010-01-01     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN
# 2010-01-04     NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN  0.006
# 2010-01-05   0.002   0.000  -0.000   0.006  0.018  0.003  0.003 -0.034 -0.003
# 2010-01-06  -0.016  -0.006  -0.003  -0.018 -0.011  0.001  0.001 -0.010  0.003
# 2010-01-07  -0.002  -0.010  -0.010  -0.017  0.020  0.004  0.004 -0.005 -0.007
#
#              XAU=    GDX    GLD
# Date
# 2010-01-01    NaN    NaN    NaN
# 2010-01-04  0.022    NaN    NaN
# 2010-01-05 -0.001  0.010 -0.001
# 2010-01-06  0.018  0.024  0.016
# 2010-01-07 -0.006 -0.005 -0.006

# %%
data.pct_change().mean().plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: >

# %% [markdown]
# ## Log return

# %%
rets = np.log(data / data.shift(1))

# %%
rets.head()
# Out:
#               AAPL.O    MSFT.O    INTC.O    AMZN.O      GS.N       SPY  \
# Date
# 2010-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05  0.001727  0.000323 -0.000479  0.005883  0.017525  0.002644
# 2010-01-06 -0.016034 -0.006156 -0.003360 -0.018282 -0.010731  0.000704
# 2010-01-07 -0.001850 -0.010389 -0.009662 -0.017160  0.019379  0.004212
#
#                 .SPX      .VIX      EUR=      XAU=       GDX       GLD
# Date
# 2010-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-04       NaN       NaN  0.006125  0.021342       NaN       NaN
# 2010-01-05  0.003111 -0.035038 -0.002988 -0.001206  0.009595 -0.000911
# 2010-01-06  0.000545 -0.009868  0.003058  0.017589  0.023999  0.016365
# 2010-01-07  0.003993 -0.005233 -0.006544 -0.005814 -0.004876 -0.006207

# %%
rets['SPY'].plot(figsize=(10, 6), legend=False)
# Out:
# <Axes: xlabel='Date'>

# %%
rets.cumsum().apply(np.exp).plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Resampling

# %%
data.resample('1m', label='right').first().head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-31  30.572827   30.95   20.88  133.90  173.08  113.33  1132.99  20.04
# 2010-02-28  27.818544   28.41   19.61  118.87  153.13  109.06  1089.19  22.59
# 2010-03-31  29.855684   29.02   20.87  124.54  156.54  111.89  1115.71  19.26
# 2010-04-30  33.709966   29.16   22.39  131.81  170.22  117.80  1178.10  17.47
# 2010-05-31  38.049962   30.86   23.26  137.49  149.50  120.35  1202.26  20.19
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-31  1.4323  1096.35  47.71  109.80
# 2010-02-28  1.3927  1106.95  42.94  108.35
# 2010-03-31  1.3560  1116.95  44.64  109.43
# 2010-04-30  1.3581  1125.50  46.40  110.26
# 2010-05-31  1.3192  1181.90  49.88  115.73

# %%
rets.cumsum().apply(np.exp).resample('1m').last().plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics

# %%
sym = 'AAPL.O'

# %%
data = pd.DataFrame(data[sym]).dropna()
data.tail()
# Out:
#             AAPL.O
# Date
# 2018-06-25  182.17
# 2018-06-26  184.43
# 2018-06-27  184.16
# 2018-06-28  185.50
# 2018-06-29  185.11

# %%
window = 20

# %%
data[sym].rolling(window=window).mean()
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05         NaN
# 2010-01-06         NaN
# 2010-01-07         NaN
# 2010-01-08         NaN
#                 ...
# 2018-06-25    189.2060
# 2018-06-26    189.0325
# 2018-06-27    188.8655
# 2018-06-28    188.7970
# 2018-06-29    188.5405
# Name: AAPL.O, Length: 2138, dtype: float64

# %%
data['min'] = data[sym].rolling(window=window).min()
data['mean'] = data[sym].rolling(window=window).mean()
data['std'] = data[sym].rolling(window=window).std()
data['median'] = data[sym].rolling(window=window).median()
data['max'] = data[sym].rolling(window=window).max()
data['ewma'] = data[sym].ewm(halflife=0.5, min_periods=window).mean()

# %%
data.dropna().head()
# Out:
#                AAPL.O        min       mean       std     median        max  \
# Date
# 2010-02-01  27.818544  27.437544  29.580892  0.933650  29.821542  30.719969
# 2010-02-02  27.979972  27.437544  29.451249  0.968048  29.711113  30.719969
# 2010-02-03  28.461400  27.437544  29.343035  0.950665  29.685970  30.719969
# 2010-02-04  27.435687  27.435687  29.207892  1.021129  29.547113  30.719969
# 2010-02-05  27.922829  27.435687  29.099892  1.037811  29.419256  30.719969
#
#                  ewma
# Date
# 2010-02-01  27.805432
# 2010-02-02  27.936337
# 2010-02-03  28.330134
# 2010-02-04  27.659299
# 2010-02-05  27.856947

# %%
ax = data[['min', 'mean', 'max']].iloc[-200:].plot(figsize=(10, 6), style=['g--', 'r--', 'g--'], lw=0.9)
data[sym].iloc[-200:].plot(ax=ax, lw=2)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## A technical Analysis Example

# %%
data['SMA1'] = data[sym].rolling(window=42).mean()
data['SMA2'] = data[sym].rolling(window=252).mean()
data[[sym, 'SMA1', 'SMA2']].tail()
# Out:
#             AAPL.O        SMA1        SMA2
# Date
# 2018-06-25  182.17  185.606190  168.265556
# 2018-06-26  184.43  186.087381  168.418770
# 2018-06-27  184.16  186.607381  168.579206
# 2018-06-28  185.50  187.089286  168.736627
# 2018-06-29  185.11  187.470476  168.901032

# %%
data[[sym, 'SMA1', 'SMA2']].plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data['positions'] = np.where(data['SMA1'] > data['SMA2'], 1, -1)

# %%
ax = data[[sym, 'SMA1', 'SMA2', 'positions']].plot(figsize=(10, 6), secondary_y='positions')
ax.get_legend().set_bbox_to_anchor((0.25, 0.7))

# %% [markdown]
# # Regression Analysis

# %%
raw = pd.read_csv('data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)
raw.head()
# Out:
#                AAPL.O  MSFT.O  INTC.O  AMZN.O    GS.N     SPY     .SPX   .VIX  \
# Date
# 2010-01-01        NaN     NaN     NaN     NaN     NaN     NaN      NaN    NaN
# 2010-01-04  30.572827  30.950   20.88  133.90  173.08  113.33  1132.99  20.04
# 2010-01-05  30.625684  30.960   20.87  134.69  176.14  113.63  1136.52  19.35
# 2010-01-06  30.138541  30.770   20.80  132.25  174.26  113.71  1137.14  19.16
# 2010-01-07  30.082827  30.452   20.60  130.00  177.67  114.19  1141.69  19.06
#
#               EUR=     XAU=    GDX     GLD
# Date
# 2010-01-01  1.4323  1096.35    NaN     NaN
# 2010-01-04  1.4411  1120.00  47.71  109.80
# 2010-01-05  1.4368  1118.65  48.17  109.70
# 2010-01-06  1.4412  1138.50  49.34  111.51
# 2010-01-07  1.4318  1131.90  49.10  110.82

# %%
data = raw[['.SPX', '.VIX']].dropna()

# %%
data.tail()
# Out:
#                .SPX   .VIX
# Date
# 2018-06-25  2717.07  17.33
# 2018-06-26  2723.06  15.92
# 2018-06-27  2699.63  17.91
# 2018-06-28  2716.31  16.85
# 2018-06-29  2718.37  16.09

# %%
data.plot(subplots=True, figsize=(10, 6), lw=1)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
data.loc[:'2012-12-31'].plot(secondary_y='.VIX', figsize=(10, 6), lw=1)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Log return

# %%
rets = np.log(data / data.shift(1))
rets.dropna(inplace=True)
rets.head()
# Out:
#                 .SPX      .VIX
# Date
# 2010-01-05  0.003111 -0.035038
# 2010-01-06  0.000545 -0.009868
# 2010-01-07  0.003993 -0.005233
# 2010-01-08  0.002878 -0.050024
# 2010-01-11  0.001745 -0.032514

# %%
rets.plot(subplots=True, figsize=(10, 6), lw=1)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)
