# %%
def fib(n):
    if n < 2:
        return n
    else:
        return fib(n - 1) + fib(n - 2)

# %%
fib(35)
# Out:
# 9227465

# %%
def factorial(n):
    if n <= 1:
        return 1
    else:
        return n * factorial(n - 1)

# %%
factorial(5) == 120
# Out:
# True
